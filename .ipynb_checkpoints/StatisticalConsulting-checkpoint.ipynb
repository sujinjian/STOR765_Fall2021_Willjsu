# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt

# %% [markdown]
# 2.637862 is derived from the lowest value after log transform.
# Add 1 so least value isn't zero.
# Total is 3.637862
# Data is small enough to see by examination there are no missing values
# However Row 37 (Q64) had small biomass = 0, I subbed in 0.0138918.
# 0.0138918 is taken from Row 6 (Q5) as a small but non-zero value
#
# *Maybe just remove Q64 and duplicate with Q62 and Q63 (Average those 2)

# %%
data_df = pd.read_csv("Data/PUPCYCLE_statistics_edit.csv")

data_df['chl a large cells (ug/L)'] = np.log(data_df['chl a large cells (ug/L)']) + 3.637862
data_df['chl a small cells (ug/L)'] = np.log(data_df['chl a small cells (ug/L)']) + 3.637862
# Out:
# C:\Users\sujin\miniconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data_df.columns = ["Time_Point", "Shelf_Type", "Treatment", "Sample_N",
                                        "NO3", "PO4", "SiO2", "Biomass_L", "Biomass_S",
                                        "A_NO3_Uptake_L", "A_NO3_Uptake_S", "N_NO3_Uptake_L", "N_NO3_Uptake_S",
                                        "A_DIC_Uptake_L", "A_DIC_Uptake_S", "N_DIC_Uptake_L", "N_DIC_Uptake_S"]

# %%
data_df_l = data_df.drop(["Biomass_S"], axis = 1)
data_df_l["Cell_Size"] = "Large"
data_df_l.rename(columns={"Biomass_L": "Biomass"}, inplace = True)

# %%
data_df_s = data_df.drop(["Biomass_L"], axis = 1)
data_df_s["Cell_Size"] = "Small"
data_df_s.rename(columns={"Biomass_S": "Biomass"}, inplace = True)

# %%
data_df = data_df_l.append(data_df_s)
data_df = data_df.dropna()
display(data_df)
# Out:
#    Time_Point Shelf_Type Treatment Sample_N    NO3    PO4   SiO2   Biomass  \
# 0          T0       Wide        DW       Q1  17.20  1.830  25.80 -0.031921
# 1          T0       Wide        DW       Q2  14.20  1.570  18.40 -0.470176
# 2          T0       Wide        DW       Q3  16.80  1.800  23.50 -0.586710
# 3          T1       Wide      Ctrl       Q4  14.20  1.730  18.50  0.644966
# 4          T1       Wide      Ctrl       Q5  13.30  1.570  16.80 -0.638595
# ..        ...        ...       ...      ...    ...    ...    ...       ...
# 37         T2     Narrow        Fe      Q66   5.87  0.891   8.96  3.555176
# 38         T2     Narrow        Fe      Q67   7.04  0.848  13.67  3.632467
# 39         T2     Narrow       DFB      Q68   9.78  1.150  12.08  3.307172
# 40         T2     Narrow       DFB      Q69  11.50  1.140  14.52  3.490637
# 41         T2     Narrow       DFB      Q70  11.00  1.190  11.96  3.392657
#
#     A_NO3_Uptake_L  A_NO3_Uptake_S  N_NO3_Uptake_L  N_NO3_Uptake_S  \
# 0         0.017649        0.021613        0.088876        0.075180
# 1         0.025079        0.023497        0.050533        0.067466
# 2         0.031617        0.060366        0.132286        0.156068
# 3         0.043921        0.018623        0.193321        0.066100
# 4         0.031993        0.019832        0.125148        0.081487
# ..             ...             ...             ...             ...
# 37        3.061907        0.229678        0.277570        0.141166
# 38        6.203433        0.290541        0.433700        0.228491
# 39        0.324906        0.524122        0.132740        0.233132
# 40        0.862018        0.324181        0.217009        0.247702
# 41        0.508727        0.395070        0.174500        0.274584
#
#     A_DIC_Uptake_L  A_DIC_Uptake_S  N_DIC_Uptake_L  N_DIC_Uptake_S Cell_Size
# 0         0.059529        0.040746          0.0701          0.0455     Large
# 1         0.159076        0.059443          0.0166          0.0128     Large
# 2         0.079004        0.073758          0.0551          0.0428     Large
# 3         0.088369        0.035445          0.1979          0.0428     Large
# 4         0.019484        0.046179          0.1684          0.0705     Large
# ..             ...             ...             ...             ...       ...
# 37       85.133018        4.603926          1.3150          0.5453     Small
# 38      136.957122        4.061551          1.5902          0.7095     Small
# 39        9.427157        9.106643          0.6159          0.5283     Small
# 40       20.599539        5.080398          0.8069          0.6308     Small
# 41       12.538206        5.066525          0.7114          0.6782     Small
#
# [83 rows x 17 columns]

# %%
Group_Wide = data_df[data_df["Shelf_Type"] == "Wide"]
Group_Narrow = data_df[data_df["Shelf_Type"] == "Narrow"]

# %%
#2.A
#find variance of each group

print("Wide Shelf:")
print(np.var(Group_Wide["Biomass"]))

print("Narrow Shelf:")
print(np.var(Group_Narrow["Biomass"]))

print("Ratio:")
print(np.var(Group_Narrow["Biomass"])/np.var(Group_Wide["Biomass"]))
# Out:
# Wide Shelf:
# 1.5749373258219899
# Narrow Shelf:
# 2.2546153025722244
# Ratio:
# 1.4315587456126215

# %%
#Perform two sample t-test with equal variances
stats.ttest_ind(a=Group_Wide["Biomass"], b=Group_Narrow["Biomass"], equal_var=True)
# Out:
# Ttest_indResult(statistic=-8.156161199463526, pvalue=3.698034200968451e-12)

# %% [markdown]
# T-Statistic: -8.156161199463526
#
# P-Value: 0.000000000003698034200968451
#
# 0.000000000003698034200968451 is not greater than 0.05
#
# We have sufficient evidence to say the two groups(Wide and Narrow) are different

# %% [markdown]
# Make sure data is fit for Anova:
# 1) Remove T0 since it does not have treatment
# 2) Plot out residuals, make sure normally dist

# %%
data_df_anova = data_df[data_df["Time_Point"] != "T0"]
data_df_anova
# Out:
#    Time_Point Shelf_Type Treatment Sample_N    NO3    PO4   SiO2   Biomass  \
# 3          T1       Wide      Ctrl       Q4  14.20  1.730  18.50  0.644966
# 4          T1       Wide      Ctrl       Q5  13.30  1.570  16.80 -0.638595
# 5          T1       Wide      Ctrl       Q6  17.10  1.960  23.70  1.022728
# 6          T1       Wide        Fe       Q7  15.50  1.770  20.80  0.367072
# 7          T1       Wide        Fe       Q8  16.30  1.900  22.20  0.217959
# ..        ...        ...       ...      ...    ...    ...    ...       ...
# 37         T2     Narrow        Fe      Q66   5.87  0.891   8.96  3.555176
# 38         T2     Narrow        Fe      Q67   7.04  0.848  13.67  3.632467
# 39         T2     Narrow       DFB      Q68   9.78  1.150  12.08  3.307172
# 40         T2     Narrow       DFB      Q69  11.50  1.140  14.52  3.490637
# 41         T2     Narrow       DFB      Q70  11.00  1.190  11.96  3.392657
#
#     A_NO3_Uptake_L  A_NO3_Uptake_S  N_NO3_Uptake_L  N_NO3_Uptake_S  \
# 3         0.043921        0.018623        0.193321        0.066100
# 4         0.031993        0.019832        0.125148        0.081487
# 5         0.045435        0.047304        0.214233        0.176613
# 6         0.036513        0.019822        0.240498        0.065574
# 7         0.040089        0.026857        0.198671        0.094496
# ..             ...             ...             ...             ...
# 37        3.061907        0.229678        0.277570        0.141166
# 38        6.203433        0.290541        0.433700        0.228491
# 39        0.324906        0.524122        0.132740        0.233132
# 40        0.862018        0.324181        0.217009        0.247702
# 41        0.508727        0.395070        0.174500        0.274584
#
#     A_DIC_Uptake_L  A_DIC_Uptake_S  N_DIC_Uptake_L  N_DIC_Uptake_S Cell_Size
# 3         0.088369        0.035445          0.1979          0.0428     Large
# 4         0.019484        0.046179          0.1684          0.0705     Large
# 5         0.137413        0.063333          0.1326          0.0785     Large
# 6         0.011231        0.065944          0.2203          0.0619     Large
# 7         0.146125        0.052890          0.1306          0.0816     Large
# ..             ...             ...             ...             ...       ...
# 37       85.133018        4.603926          1.3150          0.5453     Small
# 38      136.957122        4.061551          1.5902          0.7095     Small
# 39        9.427157        9.106643          0.6159          0.5283     Small
# 40       20.599539        5.080398          0.8069          0.6308     Small
# 41       12.538206        5.066525          0.7114          0.6782     Small
#
# [71 rows x 17 columns]

# %%
#Q-Q Plot to test data is normally dist

stats.probplot(data_df_anova[data_df_anova['Shelf_Type'] == "Wide"]['Biomass'], dist="norm", plot=plt)
plt.title("Probability Plot - " +  "Wide")
plt.show()

# %%
stats.probplot(data_df_anova[data_df_anova['Shelf_Type'] == "Narrow"]['Biomass'], dist="norm", plot=plt)
plt.title("Probability Plot - " +  "Narrow")
plt.show()

# %% [markdown]
# The data is normally distributed

# %%
#2.B
#4-Way Anova (Shelf by time by treatment by cell size)

data_df_anova_2B = data_df_anova[["Shelf_Type", "Time_Point", "Treatment", "Cell_Size","Biomass"]]

model = ols('Biomass ~ C(Shelf_Type) + C(Time_Point) + C(Treatment)+C(Cell_Size) + C(Shelf_Type):C(Time_Point) +'
            + 'C(Shelf_Type):C(Treatment) +C(Shelf_Type):C(Cell_Size) +C(Time_Point):C(Treatment) +C(Time_Point):C(Cell_Size) +C(Treatment):C(Cell_Size)' , 
            data= data_df_anova_2B).fit()
#print(model.summary())
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                                  sum_sq    df           F        PR(>F)
# C(Shelf_Type)                118.025522   1.0  333.834975  2.903599e-25
# C(Time_Point)                 41.409786   1.0  117.127504  2.411371e-15
# C(Treatment)                   6.813739   2.0    9.636324  2.531765e-04
# C(Cell_Size)                  45.090934   1.0  127.539626  4.640330e-16
# C(Shelf_Type):C(Time_Point)    0.007407   1.0    0.020951  8.854310e-01
# C(Shelf_Type):C(Treatment)     3.543036   2.0    5.010735  9.955877e-03
# C(Shelf_Type):C(Cell_Size)     8.222155   1.0   23.256351  1.127088e-05
# C(Time_Point):C(Treatment)     2.387227   2.0    3.376134  4.127061e-02
# C(Time_Point):C(Cell_Size)     2.166151   1.0    6.126954  1.636570e-02
# C(Treatment):C(Cell_Size)      1.301919   2.0    1.841238  1.680945e-01
# Residual                      19.798492  56.0         NaN           NaN

# %% [markdown]
# A variable must have p-value < 0.05 to be statistically significant
#
# So all variables except Shelf_Type, Time_Point Interaction and Treatment,Cell_Size Interaction have significant effect on the outcome (Biomass)

# %%
#2.C
#T0 Only 2-Sample T-Test
data_df_T0 = data_df[data_df["Time_Point"] == "T0"]
Group_Wide_T0 = data_df_T0[data_df_T0["Shelf_Type"] == "Wide"]
Group_Narrow_T0 = data_df_T0[data_df_T0["Shelf_Type"] == "Narrow"]

#find variance of each group

print("Wide Shelf:")
print(np.var(Group_Wide_T0["Biomass"]))

print("Narrow Shelf:")
print(np.var(Group_Narrow_T0["Biomass"]))

print("Ratio:")
print(np.var(Group_Narrow_T0["Biomass"])/np.var(Group_Wide_T0["Biomass"]))
# Out:
# Wide Shelf:
# 0.047603384644862246
# Narrow Shelf:
# 0.4218020536898855
# Ratio:
# 8.860757629665938

# %%
#perform two sample t-test
stats.ttest_ind(a=Group_Wide_T0["Biomass"], b=Group_Narrow_T0["Biomass"], equal_var=False)
# Out:
# Ttest_indResult(statistic=-7.575666526926777, pvalue=0.00025119033462612047)

# %% [markdown]
# T-Statistic: -7.575666526926777
#
# P-Value: 0.00025119033462612047
#
# 0.00025119033462612047 is not greater than 0.05
#
# We have sufficient evidence to say the two groups(Narrow and Wide) are different

# %%
#3: ANOVA but for uptake and Nutrient concentration 


data_df_anova_3 = data_df_anova[["Time_Point", "Shelf_Type", "Treatment", "Sample_N",
                                        "NO3", "PO4", "SiO2", "Biomass",
                                        "A_NO3_Uptake_L", "A_NO3_Uptake_S", "N_NO3_Uptake_L", "N_NO3_Uptake_S",
                                        "A_DIC_Uptake_L", "A_DIC_Uptake_S", "N_DIC_Uptake_L", "N_DIC_Uptake_S", "Cell_Size"]]
data_df_anova_3
# Out:
#    Time_Point Shelf_Type Treatment Sample_N    NO3    PO4   SiO2   Biomass  \
# 3          T1       Wide      Ctrl       Q4  14.20  1.730  18.50  0.644966
# 4          T1       Wide      Ctrl       Q5  13.30  1.570  16.80 -0.638595
# 5          T1       Wide      Ctrl       Q6  17.10  1.960  23.70  1.022728
# 6          T1       Wide        Fe       Q7  15.50  1.770  20.80  0.367072
# 7          T1       Wide        Fe       Q8  16.30  1.900  22.20  0.217959
# ..        ...        ...       ...      ...    ...    ...    ...       ...
# 37         T2     Narrow        Fe      Q66   5.87  0.891   8.96  3.555176
# 38         T2     Narrow        Fe      Q67   7.04  0.848  13.67  3.632467
# 39         T2     Narrow       DFB      Q68   9.78  1.150  12.08  3.307172
# 40         T2     Narrow       DFB      Q69  11.50  1.140  14.52  3.490637
# 41         T2     Narrow       DFB      Q70  11.00  1.190  11.96  3.392657
#
#     A_NO3_Uptake_L  A_NO3_Uptake_S  N_NO3_Uptake_L  N_NO3_Uptake_S  \
# 3         0.043921        0.018623        0.193321        0.066100
# 4         0.031993        0.019832        0.125148        0.081487
# 5         0.045435        0.047304        0.214233        0.176613
# 6         0.036513        0.019822        0.240498        0.065574
# 7         0.040089        0.026857        0.198671        0.094496
# ..             ...             ...             ...             ...
# 37        3.061907        0.229678        0.277570        0.141166
# 38        6.203433        0.290541        0.433700        0.228491
# 39        0.324906        0.524122        0.132740        0.233132
# 40        0.862018        0.324181        0.217009        0.247702
# 41        0.508727        0.395070        0.174500        0.274584
#
#     A_DIC_Uptake_L  A_DIC_Uptake_S  N_DIC_Uptake_L  N_DIC_Uptake_S Cell_Size
# 3         0.088369        0.035445          0.1979          0.0428     Large
# 4         0.019484        0.046179          0.1684          0.0705     Large
# 5         0.137413        0.063333          0.1326          0.0785     Large
# 6         0.011231        0.065944          0.2203          0.0619     Large
# 7         0.146125        0.052890          0.1306          0.0816     Large
# ..             ...             ...             ...             ...       ...
# 37       85.133018        4.603926          1.3150          0.5453     Small
# 38      136.957122        4.061551          1.5902          0.7095     Small
# 39        9.427157        9.106643          0.6159          0.5283     Small
# 40       20.599539        5.080398          0.8069          0.6308     Small
# 41       12.538206        5.066525          0.7114          0.6782     Small
#
# [71 rows x 17 columns]

# %%
Uptake = ["A_NO3_Uptake_L", "A_NO3_Uptake_S", "N_NO3_Uptake_L", "N_NO3_Uptake_S",
          "A_DIC_Uptake_L", "A_DIC_Uptake_S", "N_DIC_Uptake_L", "N_DIC_Uptake_S"]

for y in Uptake:
    print(y)
    model = ols(y + '~ C(Shelf_Type) + C(Time_Point) + C(Treatment) + C(Cell_Size)', data= data_df_anova_3).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    display(anova_table)
# Out:
# A_NO3_Uptake_L
#                    sum_sq    df          F        PR(>F)
# C(Shelf_Type)   77.439795   1.0  31.260542  4.820180e-07
# C(Time_Point)   45.225897   1.0  18.256583  6.437615e-05
# C(Treatment)    35.720067   2.0   7.209657  1.486226e-03
# C(Cell_Size)     0.000058   1.0   0.000024  9.961469e-01
# Residual       161.020456  65.0        NaN           NaN
# A_NO3_Uptake_S
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  1.286851   1.0  34.205596  1.760851e-07
# C(Time_Point)  0.571326   1.0  15.186342  2.329055e-04
# C(Treatment)   0.102929   2.0   1.367977  2.618535e-01
# C(Cell_Size)   0.000128   1.0   0.003406  9.536396e-01
# Residual       2.445369  65.0        NaN           NaN
# N_NO3_Uptake_L
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  0.912955   1.0  38.828812  3.859097e-08
# C(Time_Point)  0.101392   1.0   4.312308  4.179546e-02
# C(Treatment)   0.936379   2.0  19.912527  1.797084e-07
# C(Cell_Size)   0.000365   1.0   0.015540  9.011784e-01
# Residual       1.528300  65.0        NaN           NaN
# N_NO3_Uptake_S
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  0.371372   1.0  83.240702  3.002231e-13
# C(Time_Point)  0.000706   1.0   0.158216  6.921074e-01
# C(Treatment)   0.020102   2.0   2.252906  1.132394e-01
# C(Cell_Size)   0.000076   1.0   0.017072  8.964474e-01
# Residual       0.289992  65.0        NaN           NaN
# A_DIC_Uptake_L
#                      sum_sq    df          F        PR(>F)
# C(Shelf_Type)  28155.813570   1.0  32.937431  2.705867e-07
# C(Time_Point)  23562.300573   1.0  27.563816  1.790799e-06
# C(Treatment)   11536.584359   2.0   6.747904  2.173572e-03
# C(Cell_Size)       0.148105   1.0   0.000173  9.895383e-01
# Residual       55563.770787  65.0        NaN           NaN
# A_DIC_Uptake_S
#                     sum_sq    df          F    PR(>F)
# C(Shelf_Type)   277.620826   1.0  17.717935  0.000080
# C(Time_Point)   225.448489   1.0  14.388264  0.000329
# C(Treatment)     36.217938   2.0   1.155726  0.321213
# C(Cell_Size)      0.074277   1.0   0.004740  0.945320
# Residual       1018.479500  65.0        NaN       NaN
# N_DIC_Uptake_L
#                  sum_sq    df           F        PR(>F)
# C(Shelf_Type)  6.478768   1.0  105.890420  2.819729e-15
# C(Time_Point)  3.205132   1.0   52.385395  6.584623e-10
# C(Treatment)   5.441454   2.0   44.468168  6.777927e-13
# C(Cell_Size)   0.001334   1.0    0.021802  8.830714e-01
# Residual       3.976940  65.0         NaN           NaN
# N_DIC_Uptake_S
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  2.023565   1.0  86.625012  1.429781e-13
# C(Time_Point)  0.958762   1.0  41.042794  1.913135e-08
# C(Treatment)   0.106006   2.0   2.268949  1.115536e-01
# C(Cell_Size)   0.000004   1.0   0.000150  9.902604e-01
# Residual       1.518404  65.0        NaN           NaN

# %% [markdown]
# Statistically Significant:
#
# A_NO3_Uptake_L: Shelf_Type, Time_Point, Treatment
#
# A_NO3_Uptake_S: Shelf_Type, Time_Point
#
# N_NO3_Uptake_L: Shelf_Type, Time_Point, Treatment
#
# N_NO3_Uptake_S: Shelf_Type
#
# A_DIC_Uptake_L: Shelf_Type, Time_Point, Treatment
#
# A_DIC_Uptake_S: Shelf_Type, Time_Point
#
# N_DIC_Uptake_L: Shelf_Type, Time_Point, Treatment
#
# N_DIC_Uptake_S: Shelf_Type, Time_Point

# %%
#Nutrient Anova

Nutrient = ["NO3", "PO4", "SiO2"]


for y in Uptake:
    print(y)
    model = ols(y + '~ C(Shelf_Type) + C(Time_Point) + C(Treatment) + C(Cell_Size)', data= data_df_anova_3).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    display(anova_table)
# Out:
# A_NO3_Uptake_L
#                    sum_sq    df          F        PR(>F)
# C(Shelf_Type)   77.439795   1.0  31.260542  4.820180e-07
# C(Time_Point)   45.225897   1.0  18.256583  6.437615e-05
# C(Treatment)    35.720067   2.0   7.209657  1.486226e-03
# C(Cell_Size)     0.000058   1.0   0.000024  9.961469e-01
# Residual       161.020456  65.0        NaN           NaN
# A_NO3_Uptake_S
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  1.286851   1.0  34.205596  1.760851e-07
# C(Time_Point)  0.571326   1.0  15.186342  2.329055e-04
# C(Treatment)   0.102929   2.0   1.367977  2.618535e-01
# C(Cell_Size)   0.000128   1.0   0.003406  9.536396e-01
# Residual       2.445369  65.0        NaN           NaN
# N_NO3_Uptake_L
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  0.912955   1.0  38.828812  3.859097e-08
# C(Time_Point)  0.101392   1.0   4.312308  4.179546e-02
# C(Treatment)   0.936379   2.0  19.912527  1.797084e-07
# C(Cell_Size)   0.000365   1.0   0.015540  9.011784e-01
# Residual       1.528300  65.0        NaN           NaN
# N_NO3_Uptake_S
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  0.371372   1.0  83.240702  3.002231e-13
# C(Time_Point)  0.000706   1.0   0.158216  6.921074e-01
# C(Treatment)   0.020102   2.0   2.252906  1.132394e-01
# C(Cell_Size)   0.000076   1.0   0.017072  8.964474e-01
# Residual       0.289992  65.0        NaN           NaN
# A_DIC_Uptake_L
#                      sum_sq    df          F        PR(>F)
# C(Shelf_Type)  28155.813570   1.0  32.937431  2.705867e-07
# C(Time_Point)  23562.300573   1.0  27.563816  1.790799e-06
# C(Treatment)   11536.584359   2.0   6.747904  2.173572e-03
# C(Cell_Size)       0.148105   1.0   0.000173  9.895383e-01
# Residual       55563.770787  65.0        NaN           NaN
# A_DIC_Uptake_S
#                     sum_sq    df          F    PR(>F)
# C(Shelf_Type)   277.620826   1.0  17.717935  0.000080
# C(Time_Point)   225.448489   1.0  14.388264  0.000329
# C(Treatment)     36.217938   2.0   1.155726  0.321213
# C(Cell_Size)      0.074277   1.0   0.004740  0.945320
# Residual       1018.479500  65.0        NaN       NaN
# N_DIC_Uptake_L
#                  sum_sq    df           F        PR(>F)
# C(Shelf_Type)  6.478768   1.0  105.890420  2.819729e-15
# C(Time_Point)  3.205132   1.0   52.385395  6.584623e-10
# C(Treatment)   5.441454   2.0   44.468168  6.777927e-13
# C(Cell_Size)   0.001334   1.0    0.021802  8.830714e-01
# Residual       3.976940  65.0         NaN           NaN
# N_DIC_Uptake_S
#                  sum_sq    df          F        PR(>F)
# C(Shelf_Type)  2.023565   1.0  86.625012  1.429781e-13
# C(Time_Point)  0.958762   1.0  41.042794  1.913135e-08
# C(Treatment)   0.106006   2.0   2.268949  1.115536e-01
# C(Cell_Size)   0.000004   1.0   0.000150  9.902604e-01
# Residual       1.518404  65.0        NaN           NaN

# %% [markdown]
# NO3:  Shelf_Type, Time_Point
# PO4:  Shelf_Type, Time_Point, Treatment
# SiO2: Shelf_Type

# %%
#Post-hoc Anova Test
#Anova for treatments
from bioinfokit.analys import stat

res = stat()
res.tukey_hsd(df=data_df_anova, res_var='Biomass', xfac_var='Treatment', anova_model='Biomass ~ C(Shelf_Type) + C(Time_Point) + C(Treatment)+C(Cell_Size)')
res.tukey_summary
# Out:
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.098541 -0.434260  0.631341  0.627355  0.890111
# 1   Ctrl    DFB  0.655409  0.128307  1.182511  4.217735  0.011068
# 2     Fe    DFB  0.753950  0.221149  1.286750  4.799979  0.003330

# %%
data_df_anova_Narrow = data_df_anova[data_df_anova['Shelf_Type'] == "Narrow"]
data_df_anova_Wide = data_df_anova[data_df_anova['Shelf_Type'] == "Wide"]

# %%
#Anova on Uptake on Narrow Shelf

Uptake = ["A_NO3_Uptake_L", "A_NO3_Uptake_S", "N_NO3_Uptake_L", "N_NO3_Uptake_S",
          "A_DIC_Uptake_L", "A_DIC_Uptake_S", "N_DIC_Uptake_L", "N_DIC_Uptake_S"]



for y in Uptake:
    print(y + " Narrow")
    res = stat()
    res.tukey_hsd(df=data_df_anova_Narrow, res_var= y, xfac_var= "Treatment", anova_model= y + ' ~  C(Time_Point) + C(Treatment)')
    display(res.tukey_summary)
# Out:
# A_NO3_Uptake_L Narrow
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  1.136395 -0.602947  2.875737  2.270108  0.258331
# 1   Ctrl    DFB  2.116227  0.376885  3.855569  4.227459  0.014359
# 2     Fe    DFB  3.252622  1.513280  4.991964  6.497567  0.001000
# A_NO3_Uptake_S Narrow
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.182816 -0.059056  0.424688  2.626221  0.167847
# 1   Ctrl    DFB  0.151080 -0.090791  0.392952  2.170326  0.288938
# 2     Fe    DFB  0.031736 -0.210136  0.273608  0.455895  0.900000
# N_NO3_Uptake_L Narrow
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.045721 -0.071979  0.163421  1.349712  0.604064
# 1   Ctrl    DFB  0.283669  0.165970  0.401369  8.374116  0.001000
# 2     Fe    DFB  0.329390  0.211690  0.447090  9.723828  0.001000
# N_NO3_Uptake_S Narrow
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.008831 -0.051704  0.069367  0.506892  0.900000
# 1   Ctrl    DFB  0.022448 -0.038087  0.082984  1.288478  0.628741
# 2     Fe    DFB  0.013617 -0.046919  0.074153  0.781587  0.833043
# A_DIC_Uptake_L Narrow
#   group1 group2       Diff      Lower      Upper   q-value   p-value
# 0   Ctrl     Fe  19.874785  -8.574834  48.324404  2.427326  0.214854
# 1   Ctrl    DFB  39.210510  10.760892  67.660129  4.788816  0.005225
# 2     Fe    DFB  59.085295  30.635677  87.534914  7.216143  0.001000
# A_DIC_Uptake_S Narrow
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  3.543848 -1.434424  8.522120  2.473424  0.203149
# 1   Ctrl    DFB  2.599521 -2.378751  7.577794  1.814333  0.416488
# 2     Fe    DFB  0.944327 -4.033946  5.922599  0.659092  0.882414
# N_DIC_Uptake_L Narrow
#   group1 group2      Diff     Lower     Upper    q-value   p-value
# 0   Ctrl     Fe  0.045550 -0.075394  0.166494   1.308594  0.620635
# 1   Ctrl    DFB  0.558217  0.437272  0.679161  16.036855  0.001000
# 2     Fe    DFB  0.603767  0.482822  0.724711  17.345448  0.001000
# N_DIC_Uptake_S Narrow
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.066367 -0.035003  0.167737  2.274800  0.256948
# 1   Ctrl    DFB  0.074850 -0.026520  0.176220  2.565577  0.181169
# 2     Fe    DFB  0.008483 -0.092887  0.109853  0.290777  0.900000

# %%
#Anova on Uptake on Wide Shelf

Uptake = ["A_NO3_Uptake_L", "A_NO3_Uptake_S", "N_NO3_Uptake_L", "N_NO3_Uptake_S",
          "A_DIC_Uptake_L", "A_DIC_Uptake_S", "N_DIC_Uptake_L", "N_DIC_Uptake_S"]



for y in Uptake:
    print(y + " Wide")
    res = stat()
    res.tukey_hsd(df=data_df_anova_Wide, res_var= y, xfac_var= "Treatment", anova_model= y + ' ~  C(Time_Point) + C(Treatment)')
    display(res.tukey_summary)
# Out:
# A_NO3_Uptake_L Wide
#   group1 group2      Diff     Lower     Upper   q-value  p-value
# 0   Ctrl     Fe  0.013070 -0.065159  0.091299  0.581391    0.900
# 1   Ctrl    DFB  0.160539  0.084030  0.237049  7.301895    0.001
# 2     Fe    DFB  0.173609  0.095380  0.251838  7.722785    0.001
# A_NO3_Uptake_S Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.036239 -0.011941  0.084418  2.617476  0.170252
# 1   Ctrl    DFB  0.011769 -0.035351  0.058889  0.869185  0.797987
# 2     Fe    DFB  0.048008 -0.000171  0.096187  3.467556  0.050974
# N_NO3_Uptake_L Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.019393 -0.055524  0.094310  0.900825  0.785233
# 1   Ctrl    DFB  0.163275  0.090005  0.236545  7.754665  0.001000
# 2     Fe    DFB  0.182668  0.107751  0.257585  8.485037  0.001000
# N_NO3_Uptake_S Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.038636 -0.030708  0.107981  1.938885  0.369094
# 1   Ctrl    DFB  0.030291 -0.037530  0.098111  1.554245  0.521842
# 2     Fe    DFB  0.068927 -0.000418  0.138271  3.458966  0.051656
# A_DIC_Uptake_L Wide
#   group1 group2      Diff     Lower     Upper   q-value  p-value
# 0   Ctrl     Fe  0.153124 -1.099021  1.405269  0.425558    0.900
# 1   Ctrl    DFB  2.459105  1.234483  3.683727  6.987884    0.001
# 2     Fe    DFB  2.612229  1.360084  3.864374  7.259844    0.001
# A_DIC_Uptake_S Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.516376 -0.183260  1.216012  2.568412  0.181033
# 1   Ctrl    DFB  0.103980 -0.580277  0.788237  0.528811  0.900000
# 2     Fe    DFB  0.620356 -0.079280  1.319991  3.085599  0.090179
# N_DIC_Uptake_L Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.063962 -0.210285  0.338209  0.811618  0.821192
# 1   Ctrl    DFB  0.565617  0.297398  0.833836  7.338434  0.001000
# 2     Fe    DFB  0.629579  0.355332  0.903826  7.988747  0.001000
# N_DIC_Uptake_S Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.152236 -0.025193  0.329666  2.985820  0.103959
# 1   Ctrl    DFB  0.043117 -0.130413  0.216646  0.864655  0.799811
# 2     Fe    DFB  0.195353  0.017924  0.372782  3.831469  0.028501

# %%
#Anova on Nutrients on Narrow Shelf

Nutrient = ["NO3", "PO4", "SiO2"]


for y in Nutrient:
    print(y + " Wide")
    res = stat()
    res.tukey_hsd(df=data_df_anova_Narrow, res_var= y, xfac_var= "Treatment", anova_model= y + ' ~  C(Time_Point) + C(Treatment)')
    display(res.tukey_summary)
# Out:
# NO3 Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.506667 -1.969385  2.982718  0.710992  0.861495
# 1   Ctrl    DFB  1.028333 -1.447718  3.504385  1.443033  0.566452
# 2     Fe    DFB  0.521667 -1.954385  2.997718  0.732041  0.853012
# PO4 Wide
#   group1 group2    Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  0.0355 -0.126405  0.197405  0.761851  0.840998
# 1   Ctrl    DFB  0.0790 -0.082905  0.240905  1.695388  0.464183
# 2     Fe    DFB  0.1145 -0.047405  0.276405  2.457239  0.207204
# SiO2 Wide
#   group1 group2      Diff     Lower     Upper   q-value   p-value
# 0   Ctrl     Fe  1.058333 -2.137209  4.253876  1.150748  0.684255
# 1   Ctrl    DFB  0.520000 -2.675542  3.715542  0.565407  0.900000
# 2     Fe    DFB  1.578333 -1.617209  4.773876  1.716154  0.455750

# %%
#PCA

from sklearn.preprocessing import StandardScaler

data_df_PCA = data_df.reset_index(drop=True)


features = ["Biomass","A_NO3_Uptake_L", "A_NO3_Uptake_S", 
            "N_NO3_Uptake_L", "N_NO3_Uptake_S", "A_DIC_Uptake_L", "A_DIC_Uptake_S", 
            "N_DIC_Uptake_L", "N_DIC_Uptake_S"]

# Separating out the features
x = data_df_PCA.loc[:, features].values

# Separating out the target
y = data_df_PCA.loc[:,['Shelf_Type']].values


#Standardizing Features
x = StandardScaler().fit_transform(x)

# %%
display(data_df_PCA)
# Out:
#    Time_Point Shelf_Type Treatment Sample_N    NO3    PO4   SiO2   Biomass  \
# 0          T0       Wide        DW       Q1  17.20  1.830  25.80 -0.031921
# 1          T0       Wide        DW       Q2  14.20  1.570  18.40 -0.470176
# 2          T0       Wide        DW       Q3  16.80  1.800  23.50 -0.586710
# 3          T1       Wide      Ctrl       Q4  14.20  1.730  18.50  0.644966
# 4          T1       Wide      Ctrl       Q5  13.30  1.570  16.80 -0.638595
# ..        ...        ...       ...      ...    ...    ...    ...       ...
# 78         T2     Narrow        Fe      Q66   5.87  0.891   8.96  3.555176
# 79         T2     Narrow        Fe      Q67   7.04  0.848  13.67  3.632467
# 80         T2     Narrow       DFB      Q68   9.78  1.150  12.08  3.307172
# 81         T2     Narrow       DFB      Q69  11.50  1.140  14.52  3.490637
# 82         T2     Narrow       DFB      Q70  11.00  1.190  11.96  3.392657
#
#     A_NO3_Uptake_L  A_NO3_Uptake_S  N_NO3_Uptake_L  N_NO3_Uptake_S  \
# 0         0.017649        0.021613        0.088876        0.075180
# 1         0.025079        0.023497        0.050533        0.067466
# 2         0.031617        0.060366        0.132286        0.156068
# 3         0.043921        0.018623        0.193321        0.066100
# 4         0.031993        0.019832        0.125148        0.081487
# ..             ...             ...             ...             ...
# 78        3.061907        0.229678        0.277570        0.141166
# 79        6.203433        0.290541        0.433700        0.228491
# 80        0.324906        0.524122        0.132740        0.233132
# 81        0.862018        0.324181        0.217009        0.247702
# 82        0.508727        0.395070        0.174500        0.274584
#
#     A_DIC_Uptake_L  A_DIC_Uptake_S  N_DIC_Uptake_L  N_DIC_Uptake_S Cell_Size
# 0         0.059529        0.040746          0.0701          0.0455     Large
# 1         0.159076        0.059443          0.0166          0.0128     Large
# 2         0.079004        0.073758          0.0551          0.0428     Large
# 3         0.088369        0.035445          0.1979          0.0428     Large
# 4         0.019484        0.046179          0.1684          0.0705     Large
# ..             ...             ...             ...             ...       ...
# 78       85.133018        4.603926          1.3150          0.5453     Small
# 79      136.957122        4.061551          1.5902          0.7095     Small
# 80        9.427157        9.106643          0.6159          0.5283     Small
# 81       20.599539        5.080398          0.8069          0.6308     Small
# 82       12.538206        5.066525          0.7114          0.6782     Small
#
# [83 rows x 17 columns]

# %%
#Anova on Nutrients on Wide Shelf

Nutrient = ["NO3", "PO4", "SiO2"]


for y in Nutrient:
    print(y + " Narrow")
    res = stat()
    res.tukey_hsd(df=data_df_anova_Wide, res_var= y, xfac_var= "Treatment", anova_model= y + ' ~  C(Time_Point) + C(Treatment)')
    display(res.tukey_summary)

# %%
#PCA

from sklearn.decomposition import PCA

pca = PCA(n_components=6)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['PC1', 'PC2', "PC3", "PC4", "PC5", "PC6"])

principalDf
# Out:
#          PC1       PC2       PC3       PC4       PC5       PC6
# 0  -2.501970  0.758585  0.453911  0.252568 -0.113587 -0.041220
# 1  -2.734992  0.913170  0.542895  0.408002 -0.114413 -0.017430
# 2  -2.241309  0.551198  0.045859  0.804477 -0.517154 -0.120943
# 3  -2.204594  0.399627  0.393527  0.040081  0.203900 -0.188307
# 4  -2.449234  0.628421  0.386616  0.547688 -0.034100  0.206412
# ..       ...       ...       ...       ...       ...       ...
# 78  2.061065  0.517747  1.478706 -0.480107  0.260011  0.635838
# 79  3.990773 -0.131486  2.530234  0.379977 -0.292151  0.626539
# 80  1.297629  2.132963 -1.188375 -0.370073 -0.310583 -0.082122
# 81  1.387726  0.955978 -0.665115 -0.579876 -0.739403  0.405112
# 82  1.395843  1.213468 -1.045408 -0.537186 -1.041775  0.431680
#
# [83 rows x 6 columns]

# %%
PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'ro-', linewidth=2)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.show()

# %%
import matplotlib.pyplot as plt

finalDf = pd.concat([principalDf, data_df_PCA[['Shelf_Type']]], axis = 1)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Narrow', 'Wide']
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Shelf_Type'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'PC1']
               , finalDf.loc[indicesToKeep, 'PC2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Narrow', 'Wide']
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Shelf_Type'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'PC1']
               , finalDf.loc[indicesToKeep, 'PC3']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 2', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Narrow', 'Wide']
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Shelf_Type'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'PC2']
               , finalDf.loc[indicesToKeep, 'PC3']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# #

# %%
#PCA for Treatment

finalDf_treatment = pd.concat([principalDf, data_df_PCA[['Treatment']]], axis = 1)
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Crtl', 'Fe', "DFB"]
colors = ['grey', 'r', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf_treatment['Treatment'] == target
    ax.scatter(finalDf_treatment.loc[indicesToKeep, 'PC1']
               , finalDf_treatment.loc[indicesToKeep, 'PC2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
#PCA for Treatment

finalDf_treatment = pd.concat([principalDf, data_df_PCA[['Treatment']]], axis = 1)
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Crtl', 'Fe', "DFB"]
colors = ['grey', 'r', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf_treatment['Treatment'] == target
    ax.scatter(finalDf_treatment.loc[indicesToKeep, 'PC1']
               , finalDf_treatment.loc[indicesToKeep, 'PC3']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
#PCA for Treatment

finalDf_treatment = pd.concat([principalDf, data_df_PCA[['Treatment']]], axis = 1)
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Crtl', 'Fe', "DFB"]
colors = ['grey', 'r', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf_treatment['Treatment'] == target
    ax.scatter(finalDf_treatment.loc[indicesToKeep, 'PC2']
               , finalDf_treatment.loc[indicesToKeep, 'PC3']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()
